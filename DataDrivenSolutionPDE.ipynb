# %% [markdown]
# # Solving a PDE
#
#
# \begin{aligned}
# u_t(x,t) &= u_{xx}(x,t)\\
# u(x, 0) &= \sin(x)\\
# u(0,t ) &= 0\\
# u(\pi,t) &= 0.
# \end{aligned}
# with the exact solution:
# $$
# y(x) = \sin(x) e^{-t}
# $$

# %%
import torch

# %%
x = torch.linspace(0, torch.pi, 50, requires_grad=True)
t = torch.linspace(0, 1, 50, requires_grad=True)

x, t = torch.meshgrid(x, t, indexing="ij")
x = x.reshape(-1, 1)
t = t.reshape(-1, 1)

# %%
from torch import nn

# %%
mlp = nn.Sequential(
    nn.Linear(2, 10),
    nn.Tanh(),
    nn.Linear(10, 20),
    nn.Tanh(),
    nn.Linear(20, 1),
)

# %%
import torch.optim as optim

optimizer = optim.Adam(list(mlp.parameters()), lr=0.05)

# %%
def dy_dx(y, x):
    return torch.autograd.grad(
        y, x, grad_outputs=torch.ones_like(y), create_graph=True
    )[0]

# %%
losses = []

for i in range(1500):
    x_t = torch.cat((x, t), 1)
    x_0 = torch.cat((x, 0 * t), 1)
    z_t = torch.cat((0 * x, t), 1)
    pi_t = torch.cat((torch.pi + 0 * x, t), 1)

    u = mlp.forward(x_t)
    u_t = dy_dx(u, t)
    u_x = dy_dx(u, x)
    u_xx = dy_dx(u_x, x)

    residual_pde = u_t - u_xx

    residual_init = mlp.forward(x_0) - torch.sin(x)
    residual_bdy1 = mlp.forward(z_t) - 0
    residual_bdy2 = mlp.forward(pi_t) - 0

    loss = (
        (residual_pde**2).mean()
        + (residual_init**2).mean()
        + (residual_bdy1**2).mean()
        + (residual_bdy2**2).mean()
    )

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    losses.append(loss.detach().numpy())

    if i % 10 == 0:
        print("Epoch %3d: Current loss: %.2e" % (i, losses[-1]))
# Out:
# Epoch   0: Current loss: 9.61e-01
# Epoch  10: Current loss: 3.92e-01
# Epoch  20: Current loss: 2.84e-01
# Epoch  30: Current loss: 1.76e-01
# Epoch  40: Current loss: 7.62e-02
# Epoch  50: Current loss: 2.68e-02
# Epoch  60: Current loss: 9.23e-03
# Epoch  70: Current loss: 4.55e-03
# Epoch  80: Current loss: 2.62e-03
# Epoch  90: Current loss: 2.03e-03
# Epoch 100: Current loss: 1.69e-03
# Epoch 110: Current loss: 1.36e-03
# Epoch 120: Current loss: 1.16e-03
# Epoch 130: Current loss: 1.01e-03
# Epoch 140: Current loss: 8.86e-04
# Epoch 150: Current loss: 7.81e-04
# Epoch 160: Current loss: 6.92e-04
# Epoch 170: Current loss: 6.18e-04
# Epoch 180: Current loss: 5.97e-04
# Epoch 190: Current loss: 2.16e-02
# Epoch 200: Current loss: 5.95e-03
# Epoch 210: Current loss: 2.86e-03
# Epoch 220: Current loss: 9.72e-04
# Epoch 230: Current loss: 5.37e-04
# Epoch 240: Current loss: 4.49e-04
# Epoch 250: Current loss: 3.94e-04
# Epoch 260: Current loss: 3.27e-04
# Epoch 270: Current loss: 3.10e-04
# Epoch 280: Current loss: 2.89e-04
# Epoch 290: Current loss: 2.72e-04
# Epoch 300: Current loss: 2.57e-04
# Epoch 310: Current loss: 2.44e-04
# Epoch 320: Current loss: 2.33e-04
# Epoch 1050: Current loss: 9.22e-05
# Epoch 1060: Current loss: 8.89e-05
# Epoch 1070: Current loss: 8.59e-05
# Epoch 1080: Current loss: 8.31e-05
# Epoch 1090: Current loss: 8.06e-05
# Epoch 1100: Current loss: 7.82e-05
# Epoch 1110: Current loss: 7.59e-05
# Epoch 1120: Current loss: 7.38e-05
# Epoch 1130: Current loss: 7.18e-05
# Epoch 1140: Current loss: 6.99e-05
# Epoch 1150: Current loss: 6.85e-05
# Epoch 1160: Current loss: 3.57e-04
# Epoch 1170: Current loss: 3.09e-03
# Epoch 1180: Current loss: 2.88e-03
# Epoch 1190: Current loss: 1.15e-03
# Epoch 1200: Current loss: 1.19e-03
# Epoch 1210: Current loss: 2.89e-04
# Epoch 1220: Current loss: 1.74e-04
# Epoch 1230: Current loss: 9.03e-05
# Epoch 1240: Current loss: 8.76e-05
# Epoch 1250: Current loss: 7.70e-05
# Epoch 1260: Current loss: 7.06e-05
# Epoch 1270: Current loss: 6.80e-05
# Epoch 1280: Current loss: 6.56e-05
# Epoch 1290: Current loss: 6.36e-05
# Epoch 1300: Current loss: 6.17e-05
# Epoch 1310: Current loss: 5.99e-05
# Epoch 1320: Current loss: 5.83e-05
# Epoch 1330: Current loss: 5.67e-05
# Epoch 1340: Current loss: 5.53e-05
# Epoch 1350: Current loss: 5.39e-05
# Epoch 1360: Current loss: 5.25e-05
# Epoch 1370: Current loss: 5.13e-05
# Epoch 1380: Current loss: 5.01e-05
# Epoch 1390: Current loss: 4.89e-05
# Epoch 1400: Current loss: 4.78e-05
# Epoch 1410: Current loss: 4.68e-05
# Epoch 1420: Current loss: 4.74e-05
# Epoch 1430: Current loss: 7.76e-04
# Epoch 1440: Current loss: 2.57e-03
# Epoch 1450: Current loss: 5.80e-04
# Epoch 1460: Current loss: 7.98e-04
# Epoch 1470: Current loss: 4.37e-04
# Epoch 1480: Current loss: 1.16e-04
# Epoch 1490: Current loss: 8.02e-05

# %%
Nx, Nt = 31, 21
x = torch.linspace(0, torch.pi, Nx)
t = torch.linspace(0, 1, Nt)

x, t = torch.meshgrid(x, t, indexing="ij")
x = x.reshape(-1, 1)
t = t.reshape(-1, 1)
x_t = torch.cat((x, t), 1)

exact = (torch.sin(x) * torch.exp(-t)).reshape(Nx, Nt)
predict = mlp.forward(x_t).reshape(Nx, Nt)
error = exact - predict

MAE = torch.abs(error).mean()

print("Mean Absolute Error: %.2e" % MAE)
# Out:
# Mean Absolute Error: 6.87e-04

# %%
import matplotlib.pyplot as plt
import numpy as np

x = x.reshape(Nx, Nt)
t = t.reshape(Nx, Nt)

fig = plt.figure(figsize=(15, 5))
ax = fig.add_subplot(131, projection="3d")
ax.plot_surface(x, t, predict.detach().numpy(), cmap="viridis")
ax.view_init(10, 45)

ax = fig.add_subplot(132, projection="3d")
ax.plot_surface(x, t, exact.detach().numpy(), cmap="viridis")
ax.view_init(10, 45)
ax = fig.add_subplot(133, projection="3d")
ax.plot_surface(x, t, error.detach().numpy(), cmap="viridis")
ax.view_init(10, 45)
fig = plt.figure(figsize=(15, 5))
ax = fig.add_subplot(111)
ax.plot(np.log10(losses), "c", label="Loss")
